# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler
import re

# %% [markdown]
# # Clean FUS data

# %%
df = pd.read_csv("/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/final_df.csv")

# %%
df['fus_related'].value_counts()
# Out:
# 0    441
# 1     48
# Name: fus_related, dtype: int64

# %%
df.isna().sum()
# Out:
# abstract               32
# fus_related             0
# is_cardiovascular       0
# is_endocrine            0
# is_gastrointestinal     0
# is_musculoskeletal      0
# is_neurological         0
# is_womenshealth         0
# is_miscellaneous        0
# dtype: int64

# %%
df[df.isna().any(axis=1)]['fus_related'].value_counts()
# Out:
# 0    28
# 1     4
# Name: fus_related, dtype: int64

# %%
df = df.dropna()

# %%
df['fus_related'].value_counts()
# Out:
# 0    413
# 1     44
# Name: fus_related, dtype: int64

# %%
#duplicates

abstract_counts = df['abstract'].value_counts()
abstract_counts  = abstract_counts.to_frame().reset_index()
abstract_counts.columns = ['abstract', 'count']
abstract_counts
# Out:
#                                               abstract  count
# 0    Transcranial focused shockwave (FSW) is a nove...      5
# 1    PURPOSE: To develop an efficient MRI pulse seq...      4
# 2    In recent years, veterinary medicine has expan...      4
# 3    Microbubble enhanced high intensity focused ul...      4
# 4    An orthotopically allografted mouse GL26 gliom...      4
# ..                                                 ...    ...
# 325  BACKGROUND: The aim of this paper was to compa...      1
# 326  Sonodynamic therapy involving the non-invasive...      1
# 327  To improve the ultrasonic energy and realize f...      1
# 328  BACKGROUND: Transcranial ultrasound imaging an...      1
# 329  The principle of targeting brain circuits has ...      1
#
# [330 rows x 2 columns]

# %%
abstract_counts[abstract_counts['count']>1]
# Out:
#                                              abstract  count
# 0   Transcranial focused shockwave (FSW) is a nove...      5
# 1   PURPOSE: To develop an efficient MRI pulse seq...      4
# 2   In recent years, veterinary medicine has expan...      4
# 3   Microbubble enhanced high intensity focused ul...      4
# 4   An orthotopically allografted mouse GL26 gliom...      4
# ..                                                ...    ...
# 86  PURPOSE: In high-intensity focused ultrasound ...      2
# 87  Cancer is one of the diseases with high mortal...      2
# 88  Adoptive T-cell therapy against solid tumours ...      2
# 89  Focused ultrasound (FUS) peripheral neuromodul...      2
# 90  Inertial Microcavitation Rheometry (IMR) is a ...      2
#
# [91 rows x 2 columns]

# %%
df = df.drop_duplicates(subset='abstract', keep='first')

# %%
df['fus_related'].value_counts()
# Out:
# 0    286
# 1     44
# Name: fus_related, dtype: int64

# %%
# file path
file_path = '/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/ogdata_nodupes_nonas.csv'

# Save the DataFrame to a CSV file in Google Drive
df.to_csv(file_path, index=False)

# %% [markdown]
# # Undersample FUS data

# %%
#under-sampling

# Separate features (X) and target variable (y)
X = df['abstract']
y = df['fus_related']

# Initialize RandomUnderSampler
rus = RandomUnderSampler(sampling_strategy='auto', random_state=0)
# Resample the data
X_resampled, y_resampled = rus.fit_resample(X.values.reshape(-1, 1), y)

# Convert X_resampled to DataFrame
resampled_df = pd.DataFrame(X_resampled, columns=['abstract'])
resampled_df['fus_related'] = y_resampled
resampled_df['fus_related'].value_counts()
# Out:
# 0    44
# 1    44
# Name: fus_related, dtype: int64

# %%
resampled_df.isna().sum()
# Out:
# abstract       0
# fus_related    0
# dtype: int64

# %%
resampled_df['abstract'].nunique()
# Out:
# 88

# %%
resampled_df.head()
# Out:
#                                             abstract  fus_related
# 0  OBJECTIVES: To assess the comparative safety a...            0
# 1  With an ever-growing list of neurological appl...            0
# 2  We report a patient with tremor-dominant Parki...            0
# 3  BACKGROUND: Herein, a robotic system offering ...            0
# 4  BACKGROUND: Focused ultrasound (FUS) is a medi...            0

# %%
##get rid of filler words --> background + objective

# %%
# file path
file_path = '/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/resampled_data.csv'

# Save the DataFrame to a CSV file in Google Drive
resampled_df.to_csv(file_path, index=False)

# %% [markdown]
# # Concat FUS data + sean data

# %%
sean_df = pd.read_excel("/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Sean's Work/Book 3 (4).xlsx")
sean_df = sean_df.drop('Link',axis=1)

# mapping from string values to numerical representations
mapping = {'NonFus': 0, 'Fus': 1}

# use the map function
sean_df['Type'] = sean_df['Type'].map(mapping)
sean_df.rename(columns={'Summary': 'abstract', 'Type':'fus_related'}, inplace=True)
sean_df = sean_df[['abstract', 'fus_related']]

#og data without indications
df = df.iloc[:, :2]

#merge
concatenated_df = pd.concat([df, sean_df], ignore_index=True)

# %%
sean_df['fus_related'].value_counts()
# Out:
# 0    49
# 1    41
# Name: fus_related, dtype: int64

# %%
sean_df.isna().sum()
# Out:
# abstract       0
# fus_related    0
# dtype: int64

# %%
sean_df['abstract'].nunique() #no duplicates
# Out:
# 90

# %%
df['fus_related'].value_counts()
# Out:
# 0    286
# 1     44
# Name: fus_related, dtype: int64

# %%
df['abstract'].nunique() #no duplicates
# Out:
# 330

# %%
concatenated_df['fus_related'].value_counts()
# Out:
# 0    335
# 1     85
# Name: fus_related, dtype: int64

# %%
concatenated_df['abstract'].nunique() #there are duplicates
# Out:
# 418

# %%
#duplicates
concatenated_df[concatenated_df.duplicated(subset=['abstract'], keep=False)]['abstract'].value_counts()
# Out:
# Modern transcranial magnetic resonance-guided focused ultrasound is an incisionless, ablative treatment modality for a growing number of neurologic disorders. This procedure selectively destroys a targeted volume of cerebral tissue and relies on real-time MR thermography to monitor tissue temperatures. By focusing on a submillimeter target through a hemispheric phased array of transducers, ultrasound waves pass through the skull and avoid overheating and brain damage. High-intensity focused ultrasound techniques are increasingly used to create safe and effective stereotactic ablations for medication-refractory movement and other neurologic and psychiatric disorders.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2
# Administration of focused ultrasounds (US) represents an attractive complement to classical therapies for a wide range of maladies, from cancer to neurological pathologies, as they are non-invasive, easily targeted, their dosage is easy to control, and they involve low risks. Different mechanisms have been proposed for their activity but the direct effect of their interaction with cell membranes is not well understood at the molecular level. This is in part due to the difficulty of designing experiments able to probe the required spatio-temporal resolutions. Here we use Molecular Dynamics (MD) simulations at two resolution levels and machine learning (ML) classification tools to shed light on the effects that focused US mechanotherapy methods have over a range of lipid bilayers. Our results indicate that the dynamic-structural response of the membrane models to the mechanical perturbations caused by the sound waves strongly depends on the lipid composition. The analyses performed on the MD trajectories contribute to a better understanding of the behavior of lipid membranes, and to open up a path for the rational design of new therapies for the long list of diseases characterized by specific lipid profiles of pathological membrane cells.    2
# Name: abstract, dtype: int64

# %%
concatenated_df = concatenated_df.drop_duplicates(subset='abstract', keep='first')

# %%
concatenated_df['fus_related'].value_counts()
# Out:
# 0    335
# 1     83
# Name: fus_related, dtype: int64

# %%
concatenated_df
# Out:
#                                               abstract  fus_related
# 0    We investigated the effect of low-intensity fo...            1
# 1    The blood-brain barrier (BBB) protects the bra...            1
# 2    OBJECTIVE: Alzheimer's disease (AD) is often a...            1
# 3    Background Neurodegenerative disorders (such a...            1
# 4    BACKGROUND: Coronary microthromboembolism afte...            1
# ..                                                 ...          ...
# 415  The tremendous progress in engineering and com...            1
# 416  To make full use of the ability of magnetic re...            1
# 417  Various kinds of image-guided techniques have ...            1
# 418  High intensity focused ultrasound (HIFU) is ra...            1
# 419  High-intensity focused ultrasound (HIFU) is a ...            1
#
# [418 rows x 2 columns]

# %%
# file path
file_path = '/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/concatenated_data.csv'

# Save the DataFrame to a CSV file in Google Drive
concatenated_df.to_csv(file_path, index=False)

# %% [markdown]
# # Under-sampling FUS + sean data

# %%
# Separate features (X) and target variable (y)
X = concatenated_df['abstract']
y = concatenated_df['fus_related']

# Initialize RandomUnderSampler
rus = RandomUnderSampler(sampling_strategy='auto', random_state=0)
# Resample the data
X_resampled, y_resampled = rus.fit_resample(X.values.reshape(-1, 1), y)

# Convert X_resampled to DataFrame
concatenated_df2 = pd.DataFrame(X_resampled, columns=['abstract'])
concatenated_df2['fus_related'] = y_resampled
concatenated_df2['fus_related'].value_counts()
# Out:
# 0    83
# 1    83
# Name: fus_related, dtype: int64

# %%
concatenated_df2.isna().sum()
# Out:
# abstract       0
# fus_related    0
# dtype: int64

# %%
concatenated_df2['abstract'].nunique()
# Out:
# 166

# %%
# file path
file_path = '/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/concatenated_data_undersamp.csv'

# Save the DataFrame to a CSV file in Google Drive
concatenated_df2.to_csv(file_path, index=False)

# %% [markdown]
# # Access zotero data

# %%
files = []

for i in range(1, 23):
    # Read the CSV file using string formatting to construct the file path
    file_path = f"/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/zotero_data/zotero_{i}.csv"
    # Read the CSV file and append it to the list
    files.append(pd.read_csv(file_path))

# Concatenate all the DataFrames in the list into a single DataFrame
all_files = pd.concat(files, ignore_index=True)

# %%
df = pd.DataFrame(all_files['Abstract Note'])
df
# Out:
#                                           Abstract Note
# 0     INTRODUCTION: Essential tremor is the most com...
# 1     Inhibition of asparagine endopeptidase (AEP) h...
# 2     Traditional cancer treatments have been associ...
# 3     AIM: To investigate the ovarian function and p...
# 4     GOAL: To develop a low-cost magnetic resonance...
# ...                                                 ...
# 1955  Microbubbles are increasingly used in several ...
# 1956  Acoustic cavitation has found a wide range of ...
# 1957  BACKGROUND: The phase correction on transcrani...
# 1958                                                NaN
# 1959  Background: Ablative therapies have been used ...
#
# [1960 rows x 1 columns]

# %%
df.isna().sum()
# Out:
# Abstract Note    118
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum() #no nas
# Out:
# Abstract Note    0
# dtype: int64

# %%
df['fus_related'] = 1
# Out:
# <ipython-input-95-af57bfd26ecc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fus_related'] = 1

# %%
df = df.rename(columns = {'Abstract Note':'abstract'})

# %%
df
# Out:
#                                                abstract  fus_related
# 0     INTRODUCTION: Essential tremor is the most com...            1
# 1     Inhibition of asparagine endopeptidase (AEP) h...            1
# 2     Traditional cancer treatments have been associ...            1
# 3     AIM: To investigate the ovarian function and p...            1
# 4     GOAL: To develop a low-cost magnetic resonance...            1
# ...                                                 ...          ...
# 1952  Cavitation is a critical parameter in various ...            1
# 1955  Microbubbles are increasingly used in several ...            1
# 1956  Acoustic cavitation has found a wide range of ...            1
# 1957  BACKGROUND: The phase correction on transcrani...            1
# 1959  Background: Ablative therapies have been used ...            1
#
# [1842 rows x 2 columns]

# %%
df['abstract'].nunique() #there are duplicates
# Out:
# 1712

# %%
#df[df.duplicated(subset=['abstract'], keep=False)]['abstract'].value_counts()

# %%
df = df.drop_duplicates(subset='abstract', keep='first')
df
# Out:
#                                                abstract  fus_related
# 0     INTRODUCTION: Essential tremor is the most com...            1
# 1     Inhibition of asparagine endopeptidase (AEP) h...            1
# 2     Traditional cancer treatments have been associ...            1
# 3     AIM: To investigate the ovarian function and p...            1
# 4     GOAL: To develop a low-cost magnetic resonance...            1
# ...                                                 ...          ...
# 1952  Cavitation is a critical parameter in various ...            1
# 1955  Microbubbles are increasingly used in several ...            1
# 1956  Acoustic cavitation has found a wide range of ...            1
# 1957  BACKGROUND: The phase correction on transcrani...            1
# 1959  Background: Ablative therapies have been used ...            1
#
# [1712 rows x 2 columns]

# %%
nofus_df = pd.read_csv("/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/diag_zotero.csv") #non-fus data
nofus_df =  nofus_df.rename(columns = {'Abstract Note':'abstract'})
#nofus_df.columns
nofus_df.drop(columns=['Unnamed: 0'], inplace=True)
nofus_df
# Out:
#                                                abstract  fus_related
# 0     OBJECTIVE: To critically appraise and quantify...            0
# 1     OBJECTIVES: To determine whether there are cli...            0
# 2     Rationale: Delirium severity and duration are ...            0
# 3     Delirium severity has been associated with a h...            0
# 4     PURPOSE: We aimed to determine any association...            0
# ...                                                 ...          ...
# 2214  The paper touches upon the specific features o...            0
# 2215  Musculoskeletal ultrasound involves the use of...            0
# 2216  OBJECTIVE: The objective was to evaluate the f...            0
# 2217  A 44-year-old woman was admitted with obvious ...            0
# 2218  Renovascular hypertension (RVH) accounts for 5...            0
#
# [2219 rows x 2 columns]

# %%
nofus_df.isna().sum() #no nas
# Out:
# abstract       0
# fus_related    0
# dtype: int64

# %%
nofus_df['abstract'].nunique() #there are duplicates
# Out:
# 2183

# %%
#nofus_df[nofus_df.duplicated(subset=['abstract'], keep=False)]['abstract'].value_counts()

# %%
nofus_df = nofus_df.drop_duplicates(subset='abstract', keep='first')
nofus_df
# Out:
#                                                abstract  fus_related
# 0     OBJECTIVE: To critically appraise and quantify...            0
# 1     OBJECTIVES: To determine whether there are cli...            0
# 2     Rationale: Delirium severity and duration are ...            0
# 3     Delirium severity has been associated with a h...            0
# 4     PURPOSE: We aimed to determine any association...            0
# ...                                                 ...          ...
# 2214  The paper touches upon the specific features o...            0
# 2215  Musculoskeletal ultrasound involves the use of...            0
# 2216  OBJECTIVE: The objective was to evaluate the f...            0
# 2217  A 44-year-old woman was admitted with obvious ...            0
# 2218  Renovascular hypertension (RVH) accounts for 5...            0
#
# [2183 rows x 2 columns]

# %%
#add zotero data to concat data
concat_df = pd.read_csv("/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/concatenated_data.csv")
zotero_df = pd.concat([df, concat_df, nofus_df], ignore_index=True)
zotero_df['fus_related'].value_counts()
# Out:
# 0    2518
# 1    1795
# Name: fus_related, dtype: int64

# %%
zotero_df.isna().sum()
# Out:
# abstract       0
# fus_related    0
# dtype: int64

# %%
zotero_df['abstract'].nunique() #there are duplicates
# Out:
# 4311

# %%
#zotero_df[zotero_df.duplicated(subset=['abstract'], keep=False)]['abstract'].value_counts()

# %%
zotero_df = zotero_df.drop_duplicates(subset='abstract', keep='first')

# %%
zotero_df['fus_related'].value_counts()
# Out:
# 0    2517
# 1    1794
# Name: fus_related, dtype: int64

# %%
zotero_df
# Out:
#                                                abstract  fus_related
# 0     INTRODUCTION: Essential tremor is the most com...            1
# 1     Inhibition of asparagine endopeptidase (AEP) h...            1
# 2     Traditional cancer treatments have been associ...            1
# 3     AIM: To investigate the ovarian function and p...            1
# 4     GOAL: To develop a low-cost magnetic resonance...            1
# ...                                                 ...          ...
# 4308  The paper touches upon the specific features o...            0
# 4309  Musculoskeletal ultrasound involves the use of...            0
# 4310  OBJECTIVE: The objective was to evaluate the f...            0
# 4311  A 44-year-old woman was admitted with obvious ...            0
# 4312  Renovascular hypertension (RVH) accounts for 5...            0
#
# [4311 rows x 2 columns]

# %%
#undersample 0

# Separate features (X) and target variable (y)
X = zotero_df['abstract']
y = zotero_df['fus_related']

# Initialize RandomUnderSampler
rus = RandomUnderSampler(sampling_strategy='auto', random_state=0)
# Resample the data
X_resampled, y_resampled = rus.fit_resample(X.values.reshape(-1, 1), y)

# Convert X_resampled to DataFrame
zotero_df = pd.DataFrame(X_resampled, columns=['abstract'])
zotero_df['fus_related'] = y_resampled
zotero_df['fus_related'].value_counts()
# Out:
# 0    1794
# 1    1794
# Name: fus_related, dtype: int64

# %%
zotero_df['abstract'].nunique() #there are no duplicates
# Out:
# 3588

# %%
zotero_df.isna().sum()
# Out:
# abstract       0
# fus_related    0
# dtype: int64

# %%
# abstracts = [x for x in zotero_df['abstract']]
# abstracts

# %%
# pattern = r'\b([A-Za-z]+)(?::|\s)\1\b'

# # Perform the replacement
# processed_abstract = [re.sub(pattern, '', x) for x in zotero_df['abstract']]

# # Print the result to verify
# processed_abstract

# %%
zotero_df['abstract'] = [x.lower() for x in zotero_df['abstract']]
zotero_df
# Out:
#                                                abstract  fus_related
# 0     background: the intensive care environment and...            0
# 1     objectives: to determine associations between ...            0
# 2     objective: to describe methodology used to dia...            0
# 3     background: caring for lightly sedated intubat...            0
# 4     diagnostic ultrasound activates the contact ph...            0
# ...                                                 ...          ...
# 3583  high-intensity focused ultrasound (hifu) is em...            1
# 3584  the tremendous progress in engineering and com...            1
# 3585  to make full use of the ability of magnetic re...            1
# 3586  high intensity focused ultrasound (hifu) is ra...            1
# 3587  high-intensity focused ultrasound (hifu) is a ...            1
#
# [3588 rows x 2 columns]

# %%
# clean_abstract = [re.sub(r'^\w+:\s*,?', '',x,1) for x in lower_abstract]
# clean_abstract

# %%
# file path
file_path = '/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/zotero_data.csv'

# Save the DataFrame to a CSV file in Google Drive
zotero_df.to_csv(file_path, index=False)

# %% [markdown]
# # Final Sanity Check Data - Mike Reviewed Data

# %%
file1 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2023-10-02.xlsx',
                      sheet_name = 'One-to-one data')
file2 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2023-11-10.xlsx',
                     sheet_name = 'One-to-one data')
file3 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2023-12-04.xlsx',
                     sheet_name = 'One-to-one data')
file4 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2024-01-02.xlsx',
                     sheet_name = 'One-to-one data')
file5 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2024-02-01.xlsx',
                     sheet_name = 'One-to-one data')
file6 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2024-03-01.xlsx',
                     sheet_name = 'One-to-one data')
file7 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2024-04-01.xlsx',
                     sheet_name = 'One-to-one data')

# %%
df = pd.concat([file1, file2, file3, file4, file5, file6, file7], ignore_index=True)

# %%
rename_columns = {'PubMed ID':'pubmed_id',
                  'DOI Link':'doi_link',
                  'PMC Link':'pmc_link',
                  'Article Title':'article_title',
                  'ind list':'ind_list',
                  'Author List':'author_list',
                  'First / Last Author':'first_last_author',
                  'Corresponding Author(s)':'corres_author',
                  'Article Reference':'article_ref',
                  'Publication Type':'pub_type',
                  'Abstract':'abstract',
                  'Website Page':'web_page',
                  'Pubmed Link':'pubmed_link'
}
df = df.rename(rename_columns,axis=1)
df = df[['abstract']].dropna()
df['abstract'] = df['abstract'].astype(str)
df['abstract'] = [x.lower() for x in df['abstract']]

# %%
df
# Out:
#                                               abstract
# 1    transcranial focused shockwave (fsw) is a nove...
# 2    rationale and objectives: the purpose of this ...
# 3    objective: we introduce a non-invasive mr-acou...
# 4    background: moderate-to-severe acute pain is p...
# 5    objective: medial thalamotomies were introduce...
# ..                                                 ...
# 497  nanocone clusters (nccs) have been developed a...
# 498  thrombotic occlusions of large blood vessels a...
# 499  in the last decades there has been progress in...
# 500  background: diffuse midline glioma (dmg) is a ...
# 501  in this review, a systematic literature search...
#
# [465 rows x 1 columns]

# %%
#duplicates
abstract_counts = df['abstract'].value_counts()
abstract_counts  = abstract_counts.to_frame().reset_index()
abstract_counts.columns = ['abstract', 'count']
abstract_counts[abstract_counts['count']>1]
# Out:
#                                              abstract  count
# 0   transcranial focused ultrasound is a novel tec...      3
# 1   transcranial focused shockwave (fsw) is a nove...      2
# 2   the blood-brain barrier (bbb) plays a critical...      2
# 3   objective: the aim of the study described here...      2
# 4   introduction: since 1980, extracorporeal shock...      2
# ..                                                ...    ...
# 62  objective: the use of magnetic resonance-guide...      2
# 63  purpose: we reported preliminary outcomes of h...      2
# 64  background: focused ultrasound (fus) shows pro...      2
# 65  objective: skull density ratio (sdr) influence...      2
# 66  background: high resolution imaging of the mic...      2
#
# [67 rows x 2 columns]

# %%
df = df.drop_duplicates(subset='abstract', keep='first')
df
# Out:
#                                               abstract
# 1    transcranial focused shockwave (fsw) is a nove...
# 2    rationale and objectives: the purpose of this ...
# 3    objective: we introduce a non-invasive mr-acou...
# 4    background: moderate-to-severe acute pain is p...
# 5    objective: medial thalamotomies were introduce...
# ..                                                 ...
# 497  nanocone clusters (nccs) have been developed a...
# 498  thrombotic occlusions of large blood vessels a...
# 499  in the last decades there has been progress in...
# 500  background: diffuse midline glioma (dmg) is a ...
# 501  in this review, a systematic literature search...
#
# [397 rows x 1 columns]

# %%
# file path
file_path = '/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/sanity_data_tim.xlsx'

# Save the DataFrame to a CSV file in Google Drive
df.to_excel(file_path, index=False)

# %% [markdown]
# # Not Reviewed April (Mike)

# %%
file1 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Publication_data_2023-10-02 - 2024-04-01.zip (Unzipped Files)/Publication_data_2024-04-01.xlsx',
                     sheet_name = 'One-to-one data')
file2 = pd.read_excel('/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/Not_Review_April_Mike.xlsx',
                      sheet_name = 'One-to-one data')

# %%
file1
# Out:
#     PubMed ID                                           DOI Link     PMC Link  \
# 0    37482962                 https://doi.org/10.1002/jmri.28916          NaN
# 1    37491872                 https://doi.org/10.1002/jmri.28896          NaN
# 2    37657095            https://doi.org/10.3171/2023.6.JNS23171          NaN
# 3    37657096           https://doi.org/10.3171/2023.6.JNS231153          NaN
# 4    37696982         https://doi.org/10.1038/s41434-023-00421-1          NaN
# ..        ...                                                ...          ...
# 79   38551360  https://doi.org/10.1021/acs.molpharmaceut.3c01178          NaN
# 80   38553135       https://doi.org/10.1016/j.ultras.2023.107223          NaN
# 81   38553256       https://doi.org/10.1016/j.medcli.2023.12.013          NaN
# 82   38555449         https://doi.org/10.1186/s12967-024-05096-9  PMC10981822
# 83   38555851       https://doi.org/10.1016/j.ejogrb.2024.03.029          NaN
#
#                                         Article Title  \
# 0   Editorial for "Alteration of White Matter Conn...
# 1   Alteration of White Matter Connectivity for MR...
# 2   Successful magnetic resonance-guided focused u...
# 3   Consistency is key: influence of skull density...
# 4   Acoustically targeted noninvasive gene therapy...
# ..                                                ...
# 79  Investigation of Optimum Production Conditions...
# 80  Inducing cavitation within hollow cylindrical ...
# 81  Essential Tremor: Update of Therapeutic Strate...
# 82  Focused ultrasound-mediated blood-brain barrie...
# 83  Effectiveness and complication rates of high i...
#
#                                           Author List  \
# 0                              Yeo, Desmond Teck Beng
# 1   Wang, Xiaoyu; Lin, Jiaji; Lu, Haoxuan; Xiong, ...
# 2   Vetkas, Artur; Boutet, Alexandre; Sarica, Can;...
# 3   Kyle, Kain; Maamary, Joel; Jonker, Benjamin; P...
# 4   Nouraein, Shirin; Lee, Sangsin; Saenz, Vidal A...
# ..                                                ...
# 79  Mustafa, Waleed; Hall, Sarah; Huynh, Laura; Ma...
# 80  Gong, Li; Wright, Alex R; Hynynen, Kullervo; G...
# 81  Gironell, Alexandre; Marín-Lahoz, Juan; Póveda...
# 82  Tazhibi, Masih; McQuillan, Nicholas; Wei, Hong...
# 83  Knorren, Elisabeth R; de Ridder, Larissa A; Ni...
#
#             First / Last Author                Corresponding Author(s)  \
# 0                       Yeo DTB                                    NaN
# 1                Wang X / Lou X                                    NaN
# 2          Vetkas A / Lozano AM                                    NaN
# 3              Kyle K / Tisch S                                    NaN
# 4    Nouraein S / Szablowski JO                    Szablowski, Jerzy O
# ..                          ...                                    ...
# 79  Mustafa W / Yuksel Durmaz Y                                    NaN
# 80           Gong L / Goertz DE                               Gong, Li
# 81        Gironell A / Póveda S                    Gironell, Alexandre
# 82            Tazhibi M / Wu CC  Wu, Cheng-Chia; Zacharoulis, Stergios
# 83      Knorren ER / Schutte JM                   Knorren, Elisabeth R
#
#                                     Article Reference  \
# 0     J Magn Reson Imaging. 2024 Apr;59(4):1371-1372.
# 1     J Magn Reson Imaging. 2024 Apr;59(4):1358-1370.
# 2             J Neurosurg. 2024 Mar 1;140(3):639-647.
# 3             J Neurosurg. 2024 Mar 1;140(3):648-656.
# 4                  Gene Ther. 2024 Mar;31(3-4):85-94.
# ..                                                ...
# 79                            Mol Pharm. 2024 Mar 29.
# 80                  Ultrasonics. 2024 Mar;138:107223.
# 81  Med Clin (Barc). 2024 Mar 28:S0025-7753(24)000...
# 82               J Transl Med. 2024 Mar 30;22(1):320.
# 83  Eur J Obstet Gynecol Reprod Biol. 2024 Mar 26;...
#
#            Publication Type  \
# 0                 Editorial
# 1           Journal Article
# 2           Journal Article
# 3           Journal Article
# 4           Journal Article
# ..                      ...
# 79          Journal Article
# 80          Journal Article
# 81  Journal Article; Review
# 82          Journal Article
# 83  Journal Article; Review
#
#                                              Abstract  Website Page  \
# 0                                                 NaN           NaN
# 1   BACKGROUND: Magnetic resonance-guided focused ...           NaN
# 2   OBJECTIVE: The use of magnetic resonance-guide...           NaN
# 3   OBJECTIVE: Skull density ratio (SDR) influence...           NaN
# 4   Focused Ultrasound Blood-Brain Barrier Opening...           NaN
# ..                                                ...           ...
# 79  Nanocone clusters (NCCs) have been developed a...           NaN
# 80  Thrombotic occlusions of large blood vessels a...           NaN
# 81  In the last decades there has been progress in...           NaN
# 82  BACKGROUND: Diffuse midline glioma (DMG) is a ...           NaN
# 83  In this review, a systematic literature search...           NaN
#
#                                 Consolidated Web Info  \
# 0   Yeo DTB. Editorial for "Alteration of White Ma...
# 1   Wang X, Lin J, Lu H, Xiong Y, Duan C, Zhang D,...
# 2   Vetkas A, Boutet A, Sarica C, Germann J, Gwun ...
# 3   Kyle K, Maamary J, Jonker B, Peters J, Barnett...
# 4   Nouraein S, Lee S, Saenz VA, Del Mundo HC, Yiu...
# ..                                                ...
# 79  Mustafa W, Hall S, Huynh L, Mannasse R, Lulebu...
# 80  Gong L, Wright AR, Hynynen K, Goertz DE. Induc...
# 81  Gironell A, Marín-Lahoz J, Póveda S. Essential...
# 82  Tazhibi M, McQuillan N, Wei HJ, Gallitto M, Be...
# 83  Knorren ER, de Ridder LA, Nijholt IM, Dijkstra...
#
#                                   Pubmed Link
# 0   https://pubmed.ncbi.nlm.nih.gov/37482962/
# 1   https://pubmed.ncbi.nlm.nih.gov/37491872/
# 2   https://pubmed.ncbi.nlm.nih.gov/37657095/
# 3   https://pubmed.ncbi.nlm.nih.gov/37657096/
# 4   https://pubmed.ncbi.nlm.nih.gov/37696982/
# ..                                        ...
# 79  https://pubmed.ncbi.nlm.nih.gov/38551360/
# 80  https://pubmed.ncbi.nlm.nih.gov/38553135/
# 81  https://pubmed.ncbi.nlm.nih.gov/38553256/
# 82  https://pubmed.ncbi.nlm.nih.gov/38555449/
# 83  https://pubmed.ncbi.nlm.nih.gov/38555851/
#
# [84 rows x 13 columns]

# %%
file2
# Out:
#      PubMed ID                                           DOI Link  \
# 0     35780953      https://doi.org/10.1016/j.jconrel.2022.06.042
# 1     36394665         https://doi.org/10.1007/s00404-022-06761-4
# 2     36411569  https://doi.org/10.2174/1570159X21666221121094343
# 3     36533878      https://doi.org/10.1080/10717544.2022.2157068
# 4     36575807                 https://doi.org/10.1111/nicc.12871
# ..         ...                                                ...
# 525   38585032             https://doi.org/10.12786/bn.2024.17.e5
# 526   38585361         https://doi.org/10.3389/fneur.2024.1362712
# 527   38589407         https://doi.org/10.1038/s41597-024-03197-0
# 528   38595847         https://doi.org/10.3389/fneur.2024.1345873
# 529   38595849         https://doi.org/10.3389/fneur.2024.1356310
#
#         PMC Link                                      Article Title  \
# 0            NaN  Reply to Letter from Price et al, re: Translat...
# 1    PMC10348920  Letter to the editor: Römer et al. The signifi...
# 2    PMC10964101          Surgical Advances in Parkinson's Disease.
# 3     PMC9769131  Blood-cerebrospinal fluid barrier opening by m...
# 4     PMC9880746  Intensive care nurse-led point of care ultraso...
# ..           ...                                                ...
# 525  PMC10990843  Update on Non-invasive Brain Stimulation on St...
# 526  PMC10995240  Early cortico-muscular coherence and cortical ...
# 527  PMC11002007  A large normative connectome for exploring the...
# 528  PMC11002122  The evolution of ventral intermediate nucleus ...
# 529  PMC11002896  Focused ultrasound therapy in movement disorde...
#
#                                            Author List  \
# 0    Brighi, Caterina; Salimova, Ekaterina; de Veer...
# 1                                      David, Matthias
# 2                  Hvingelby, Victor S; Pavese, Nicola
# 3    Kung, Yi; Wu, Chueh-Hung; Lin, Meng-Ting; Liao...
# 4    Corcoran, Eleanor; Hopkins, Phil; Fisher, Rich...
# ..                                                 ...
# 525                        Kim, Sejoon; Park, Hae-Yeon
# 526  Visani, Elisa; Panzica, Ferruccio; Franceschet...
# 527  Elias, Gavin J B; Germann, Jürgen; Joel, Sures...
# 528  Jameel, Ayesha; Akgun, Sena; Yousif, Nada; Smi...
# 529  Rinaldo, Sara; Cilia, Roberto; Leta, Valentina...
#
#          First / Last Author Corresponding Author(s)  \
# 0          Brighi C / Egan G              Egan, Gary
# 1                    David M         David, Matthias
# 2    Hvingelby VS / Pavese N                     NaN
# 3          Kung Y / Hsiao MY                     NaN
# 4        Corcoran E / Rose L                     NaN
# ..                       ...                     ...
# 525          Kim S / Park HY                     NaN
# 526     Visani E / Eleopra R                     NaN
# 527    Elias GJB / Lozano AM        Lozano, Andres M
# 528     Jameel A / Gedroyc W                     NaN
# 529    Rinaldo S / Eleopra R                     NaN
#
#                               Article Reference  \
# 0          J Control Release. 2024 Feb;366:879.
# 1    Arch Gynecol Obstet. 2023 Sep;308(3):1045.
# 2    Curr Neuropharmacol. 2024;22(6):1033-1046.
# 3            Drug Deliv. 2023 Dec;30(1):97-107.
# 4       Nurs Crit Care. 2023 Sep;28(5):781-788.
# ..                                          ...
# 525   Brain Neurorehabil. 2024 Jan 31;17(1):e5.
# 526       Front Neurol. 2024 Mar 22;15:1362712.
# 527             Sci Data. 2024 Apr 8;11(1):353.
# 528       Front Neurol. 2024 Mar 26;15:1345873.
# 529       Front Neurol. 2024 Feb 26;15:1356310.
#
#                                    Publication Type  \
# 0                                            Letter
# 1                                            Letter
# 2                           Review; Journal Article
# 3                                   Journal Article
# 4    Case Reports; Research Support, Non-U.S. Gov't
# ..                                              ...
# 525                         Journal Article; Review
# 526                                 Journal Article
# 527                                 Journal Article
# 528                                 Journal Article
# 529                                 Journal Article
#
#                                               Abstract  Website Page  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2    While symptomatic pharmacological therapy rema...           NaN
# 3    Transcranial focused shockwave (FSW) is a nove...           NaN
# 4    Focused ultrasound can be used to rapidly diag...           NaN
# ..                                                 ...           ...
# 525  Stroke is a leading global cause of death and ...           NaN
# 526  INTRODUCTION: To investigate cortical network ...           NaN
# 527  Diffusion-weighted MRI (dMRI) is a widely used...           NaN
# 528  BACKGROUND: The ventral intermediate nucleus (...           NaN
# 529  MRI-guided focused ultrasound (MRgFUS) lesioni...           NaN
#
#                                  Consolidated Web Info  \
# 0    Brighi C, Salimova E, de Veer M, Puttick S, Eg...
# 1    David M. Letter to the editor: Römer et al. Th...
# 2    Hvingelby VS, Pavese N. Surgical Advances in P...
# 3    Kung Y, Wu CH, Lin MT, Liao WH, Chen WS, Hsiao...
# 4    Corcoran E, Hopkins P, Fisher R, Wong A, Rose ...
# ..                                                 ...
# 525  Kim S, Park HY. Update on Non-invasive Brain S...
# 526  Visani E, Panzica F, Franceschetti S, Golfrè A...
# 527  Elias GJB, Germann J, Joel SE, Li N, Horn A, B...
# 528  Jameel A, Akgun S, Yousif N, Smith J, Jones B,...
# 529  Rinaldo S, Cilia R, Leta V, Gammone M, Andreas...
#
#                                    Pubmed Link
# 0    https://pubmed.ncbi.nlm.nih.gov/35780953/
# 1    https://pubmed.ncbi.nlm.nih.gov/36394665/
# 2    https://pubmed.ncbi.nlm.nih.gov/36411569/
# 3    https://pubmed.ncbi.nlm.nih.gov/36533878/
# 4    https://pubmed.ncbi.nlm.nih.gov/36575807/
# ..                                         ...
# 525  https://pubmed.ncbi.nlm.nih.gov/38585032/
# 526  https://pubmed.ncbi.nlm.nih.gov/38585361/
# 527  https://pubmed.ncbi.nlm.nih.gov/38589407/
# 528  https://pubmed.ncbi.nlm.nih.gov/38595847/
# 529  https://pubmed.ncbi.nlm.nih.gov/38595849/
#
# [530 rows x 13 columns]

# %%
file2['fus_related'] = file2['PubMed ID'].apply(lambda x: 1 if x in file1['PubMed ID'].values else 0)

# %%
file2['fus_related'].value_counts()
# Out:
# fus_related
# 0    446
# 1     84
# Name: count, dtype: int64

# %%
#cleaning labeled file
rename_columns = {'PubMed ID':'pubmed_id',
                  'DOI Link':'doi_link',
                  'PMC Link':'pmc_link',
                  'Article Title':'article_title',
                  'ind list':'ind_list',
                  'Author List':'author_list',
                  'First / Last Author':'first_last_author',
                  'Corresponding Author(s)':'corres_author',
                  'Article Reference':'article_ref',
                  'Publication Type':'pub_type',
                  'Abstract':'abstract',
                  'Website Page':'web_page',
                  'Pubmed Link':'pubmed_link',
}
file2 = file2.rename(rename_columns,axis=1)
file2 = file2[['abstract', 'fus_related']]
file2 = file2.dropna()
file2['abstract'] =file2['abstract'].astype(str)
file2['abstract'] = [x.lower() for x in file2['abstract']]

# %%
file2['fus_related'].value_counts()
# Out:
# fus_related
# 0    419
# 1     75
# Name: count, dtype: int64

# %%
#duplicates
abstract_counts = file2['abstract'].value_counts()
abstract_counts  = abstract_counts.to_frame().reset_index()
abstract_counts.columns = ['abstract', 'count']
abstract_counts[abstract_counts['count']>1] #no duplicates
# Out:
# Empty DataFrame
# Columns: [abstract, count]
# Index: []

# %%
# file path
file_path = '/content/drive/MyDrive/MSDS/Capstone/MSDS Capstone/Dataset/labeled_data_tim.xlsx'

# Save the DataFrame to a CSV file in Google Drive
file2.to_excel(file_path, index=False)
